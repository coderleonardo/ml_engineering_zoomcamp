# %%
#!pip install xgboost
import xgboost as xgb

import pandas as pd
import numpy as np

from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split

from sklearn.metrics import roc_auc_score


df = pd.read_csv('CreditScoring.csv')

df.columns = df.columns.str.lower()

status_values = {1: 'ok', 2: 'default', 0: 'unk'}

df.status = df.status.map(status_values)

home_values = {
    1: 'rent',
    2: 'owner',
    3: 'private',
    4: 'ignore',
    5: 'parents',
    6: 'other',
    0: 'unk'
}

df.home = df.home.map(home_values)

marital_values = {
    1: 'single',
    2: 'married',
    3: 'widow',
    4: 'separated',
    5: 'divorced',
    0: 'unk'
}

df.marital = df.marital.map(marital_values)

records_values = {
    1: 'no',
    2: 'yes',
    0: 'unk'
}

df.records = df.records.map(records_values)

job_values = {
    1: 'fixed',
    2: 'partime',
    3: 'freelance',
    4: 'others',
    0: 'unk'
}

df.job = df.job.map(job_values)

df = df.loc[df.status != 'unk'].reset_index(drop=True)

df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=11)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=11)

df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

y_train = (df_train.status == 'default').astype('int').values
y_val = (df_val.status == 'default').astype('int').values
y_test = (df_test.status == 'default').astype('int').values

del df_train['status']
del df_val['status']
del df_test['status']

df_full_train = df_full_train.reset_index(drop=True)

y_full_train = (df_full_train.status == 'default').astype(int).values

del df_full_train['status']

dicts_full_train = df_full_train.to_dict(orient='records')

dv = DictVectorizer(sparse=False)
X_full_train = dv.fit_transform(dicts_full_train)

dicts_test = df_test.to_dict(orient='records')
X_test = dv.transform(dicts_test)

dfulltrain = xgb.DMatrix(X_full_train, label=y_full_train,
                    feature_names=dv.get_feature_names())

dtest = xgb.DMatrix(X_test, feature_names=dv.get_feature_names())

xgb_params = {
    'eta': 0.1, 
    'max_depth': 3,
    'min_child_weight': 1,

    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dfulltrain, num_boost_round=175)

y_pred = model.predict(dtest)
print(roc_auc_score(y_test, y_pred))
# Out:
# 0.8295354577000146

# %%
df_full_train
# Out:
#       seniority     home  time  age  marital records        job  expenses  \
# 0            22    owner    48   48  married      no      fixed        60
# 1             8    other    60   41  married      no  freelance        45
# 2             2  parents    36   19  married      no      fixed        35
# 3             1    owner    12   61  married      no     others        45
# 4            13    owner    60   27  married      no      fixed        35
# ...         ...      ...   ...  ...      ...     ...        ...       ...
# 3558          4    owner    60   47  married      no  freelance        75
# 3559          2     rent    60   28   single      no      fixed        45
# 3560          2  parents    36   25   single      no      fixed        35
# 3561          4    other    60   25   single      no      fixed        35
# 3562          1  parents    48   25   single      no  freelance        35
#
#       income  assets  debt  amount  price
# 0        110    3000     0    1000   1460
# 1         62       0     0    1800   2101
# 2        162    4000   100     400    570
# 3        103   20000     0     300    650
# 4        253    7000     0    1060   1750
# ...      ...     ...   ...     ...    ...
# 3558       0   13500     0    1900   1976
# 3559     101       0     0    1300   1333
# 3560     110       0     0     500   1200
# 3561     162       0     0    1800   2999
# 3562       0       0     0    1800   1809
#
# [3563 rows x 13 columns]

# %%
#!pip install bentoml
import bentoml
bentoml.__version__
# Out:
# '1.0.7'

# %%
bentoml.xgboost.save_model('credit_risk_model', model, 
                          custom_objects={
                              'dictVectorizer': dv
                          })
# Out:
# Using default model signature `{"predict": {"batchable": False}}` for XGBoost model
# Successfully saved Model(tag="credit_risk_model:njjjxekqucnzuxgn")
# Model(tag="credit_risk_model:njjjxekqucnzuxgn", path="C:\Users\l0037015\bentoml\models\credit_risk_model\njjjxekqucnzuxgn\")
